# %%
# %pylab inline
import matplotlib.pyplot as plt

import matplotlib
matplotlib.style.use('ggplot') ## gnuplot style

import numpy as np
import pandas as pd

#size
width, height=12,8
plt.rcParams['figure.figsize'] = width, height #aggiunta pt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# to chose a csv file in the current folder
import os
filesHere=os.listdir("./")
selected=[]
for i in range(len(filesHere)):
    if filesHere[i].find('.csv')>0: selected.append(filesHere[i])
for i in range(len(selected)):
    print i, selected[i]
# Out:
# 0 20160611-00:09:33.csv
# 1 20160611-13:10:15.csv

# %%
num=input("Chosse a file via its number (>=0;<="+str(len(selected)-1)+" ")
df = pd.read_csv(selected[num])
# Out:
# Chosse a file via its number (>=0;<=1 1

# %%
df
# Out:
#     unemployed  totalProfit  totalProduction  plannedProduction     price  \
# 0         2098  1756.618107             7912        7912.000000  1.222019
# 1          402  -160.135275             9608        9779.657496  0.986664
# 2          779 -1032.021517             9231        9242.289537  0.991667
# 3          845     8.663799             9165        9172.919303  1.004437
# 4          911   -15.645945             9099        9112.679499  0.998280
# 5         1100   -72.271060             8910        8921.390741  0.991889
# 6         1233   852.174615             8777        8791.524161  1.097092
# 7          301  1403.347023             9709        9723.003256  1.144541
# 8            2  -214.377866            10008       10959.635970  1.078579
# 9            0 -1324.092621            10010       10947.206826  0.967723
# 10         509 -1147.313236             9501        9518.696755  0.979243
# 11         660  1254.004767             9350        9360.891536  1.134118
# 12           0  -827.454894            10010       10805.939424  0.917337
# 13         846   701.887488             9164        9177.438143  1.176592
# 14           0  -362.052312            10010       10772.402382  0.963831
# 15         374 -1279.574199             9636        9770.398057  0.967209
# 16         486   300.204015             9524        9535.732343  1.131521
# 17           0 -1360.922013            10010       10963.088674  0.964044
# 18         384   535.689429             9626        9653.729504  1.155650
# 19           0  1063.990287            10010       11092.580103  1.206293
# 20           0   916.595077            10010       12249.844390  1.191568
# 21           0  -799.978769            10010       12225.943301  1.020082
# 22           4 -1926.064490            10006       10245.872331  0.907509
# 23         803 -1058.082701             9207        9220.900767  0.985078
# 24         756  -476.788238             9254        9265.036906  0.948478
# 25        1280 -1030.834085             8730        8741.654365  0.881920
# 26        2341  1183.240499             7669        7682.096657  1.154289
# 27        1195  1819.559681             8815        8825.372237  1.206416
# 28          93  2006.808187             9919       10192.244481  1.204579
# 29         346  -572.762005             9668       11016.275448  1.045699
# 30          99 -1186.312946             9911       10215.949498  0.985147
# 31         270 -2074.219737             9740        9761.192196  0.889710
# 32        1416  1029.483353             8594        8619.213734  1.219791
# 33           0  -224.674318            10010       10490.983934  0.977555
# 34         203    -8.186506             9807        9830.168409  1.099165
# 35           0 -1514.222805            10010       10724.997805  0.948729
# 36         623   524.459755             9387        9412.786639  1.155871
# 37           0   142.956547            10010       10877.663728  1.014281
# 38           0  -620.750035            10010       10180.100925  1.037987
# 39           8  -308.044570            10002       10480.172579  1.069202
# 40           0 -2070.127808            10010       10616.009130  0.893194
# 41        1011 -1658.931116             8999        9020.963594  0.915654
# 42        1889  1143.410269             8121        8144.850504  1.140797
# 43         768  1394.636106             9242        9269.441549  1.150902
# 44           0  -873.953442            10010       10675.091664  0.912692
# 45         828 -1692.655384             9182        9210.003685  0.915655
# 46        1598   134.475857             8412        8438.775073  1.015986
# 47        1481  1101.949922             8529        8551.689145  1.129200
# 48         491  1612.762084             9519        9544.770274  1.169426
# 49           0 -1052.846977            10010       11230.279083  0.994820
#
#     wage
# 0    1.0
# 1    1.1
# 2    1.0
# 3    1.0
# 4    1.0
# 5    1.0
# 6    1.0
# 7    1.1
# 8    1.1
# 9    1.1
# 10   1.0
# 11   1.0
# 12   1.1
# 13   1.0
# 14   1.1
# 15   1.1
# 16   1.1
# 17   1.1
# 18   1.1
# 19   1.1
# 20   1.1
# 21   1.1
# 22   1.1
# 23   1.0
# 24   1.0
# 25   1.0
# 26   1.0
# 27   1.0
# 28   1.1
# 29   1.1
# 30   1.1
# 31   1.1
# 32   1.0
# 33   1.1
# 34   1.1
# 35   1.1
# 36   1.0
# 37   1.1
# 38   1.1
# 39   1.1
# 40   1.1
# 41   1.0
# 42   1.0
# 43   1.0
# 44   1.1
# 45   1.0
# 46   1.0
# 47   1.0
# 48   1.1
# 49   1.1

# %%
df.keys()
# Out:
# Index([u'unemployed', u'totalProfit', u'totalProduction', u'plannedProduction',
#        u'price', u'wage'],
#       dtype='object')

# %%
df.describe()
# Out:
#         unemployed  totalProfit  totalProduction  plannedProduction  \
# count    50.000000    50.000000        50.000000          50.000000
# mean    568.660000  -121.167600      9441.460000        9803.470955
# std     615.490367  1129.866524       615.551759        1025.952019
# min       0.000000 -2074.219737      7669.000000        7682.096657
# 25%       0.000000 -1047.640612      9164.250000        9174.049013
# 50%     393.000000  -187.256571      9617.000000        9688.366380
# 75%     845.750000   900.489961     10010.000000       10660.321031
# max    2341.000000  2006.808187     10010.000000       12249.844390
#
#            price       wage
# count  50.000000  50.000000
# mean    1.045202   1.056000
# std     0.103800   0.050143
# min     0.881920   1.000000
# 25%     0.967337   1.000000
# 50%     1.015134   1.100000
# 75%     1.143605   1.100000
# max     1.222019   1.100000

# %%
df.corr(method='pearson')
# Out:
#                    unemployed  totalProfit  totalProduction  \
# unemployed           1.000000     0.429880        -0.999999
# totalProfit          0.429880     1.000000        -0.429765
# totalProduction     -0.999999    -0.429765         1.000000
# plannedProduction   -0.897257    -0.357294         0.897350
# price                0.328689     0.909706        -0.328554
# wage                -0.823901    -0.266049         0.823994
#
#                    plannedProduction     price      wage
# unemployed                 -0.897257  0.328689 -0.823901
# totalProfit                -0.357294  0.909706 -0.266049
# totalProduction             0.897350 -0.328554  0.823994
# plannedProduction           1.000000 -0.237328  0.795942
# price                      -0.237328  1.000000 -0.165046
# wage                        0.795942 -0.165046  1.000000

# %%
df.loc[:,['unemployed','totalProfit','totalProduction','plannedProduction']].plot()

# %%
df.loc[:,['price','wage']].plot()

# %%
myPlot = df.plot(secondary_y=['price','wage']) # legend=False|True|'reverse' || mark_right=False to avoid (rightmark_right=False)
myPlot.set_ylabel('unemployed, totalProfit, totalProduction, plannedProduction')
myPlot.right_ax.set_ylabel('price, wage')

# %%
myPlot = df.plot(secondary_y=['price','wage'])
myPlot.set_ylabel('unemployed, totalProfit, totalProduction, plannedProduction')
myPlot.right_ax.set_ylabel('price, wage')
myPlot.legend(loc='upper left') #, bbox_to_anchor=(-0.35, 0.5)
myPlot.axes.right_ax.legend(loc='lower right') #, bbox_to_anchor=(1.1, 0.5)
